# %%
# %pip install langchain-community tavily-python python-dotenv
# Out:
# Requirement already satisfied: langchain-community in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: tavily-python in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (0.8.0)
# Requirement already satisfied: python-dotenv in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (1.6.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (0.11.2)
# Requirement already satisfied: numpy>=1.26.2 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (2.5.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (4.14.1)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from tavily-python) (0.14.0)
# Requirement already satisfied: regex in /opt/miniconda3/envs/a1/lib/python3.12/site-packages (from tiktoken>=0.5.1->tavily-python) (2026.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

load_dotenv()
# Out:
# /var/folders/s4/cxp4_1c1447576f31nclvwbh0000gp/T/ipykernel_76178/1783149117.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
os.environ['TAVILY_API_KEY'] = os.getenv("TAVILY_API_KEY")

# %%
search_tool = TavilySearchResults(max_results=2) 
#max_result = no. of search result to return
# Out:
# /var/folders/s4/cxp4_1c1447576f31nclvwbh0000gp/T/ipykernel_76178/412344330.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   search_tool = TavilySearchResults(max_results=2)

# %%
search_tool.description
# Out:
# 'A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query.'

# %%
search_tool.invoke("What's a 'node' in LangGraph?")
# Out:
# [{'title': 'What is LangGraph? - IBM',
#   'url': 'https://www.ibm.com/think/topics/langgraph',
#   'content': 'Nodes: In LangGraph, nodes represent individual components or agents within an AI workflow. Nodes can be thought of as “actors” that interact with each other in a specific way. For example, to add nodes for tool calling, one can use the ToolNode. Another example, the next node, refers to the node that will be executed following the current one.\n\nEdges: Edges are a function within Python that determines which node to execute next based on the current state. Edges can be conditional branches or fixed transitions.\n\n#### Tools\n\nRAG: Retrieval-augmented generation (RAG) combines the power of LLMs with contextual information from external sources by retrieving relevant documents, which are then used as input for answer generation.',
#   'score': 0.89166987},
#  {'title': 'Thinking in LangGraph - Docs by LangChain',
#   'url': 'https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph',
#   'content': 'Notice that the state contains only raw data—no prompt templates, no formatted strings, no instructions. The classification output is stored as a single dictionary, straight from the LLM.\n\n## \u200b Step 4: Build your nodes\n\nNow we implement each step as a function. A node in LangGraph is just a Python function that takes the current state and returns updates to it.\n\n### \u200b Handle errors appropriately\n\nDifferent errors need different handling strategies: [...] ## Nodes are functions\n\nThey take state, do work, and return updates. When they need to make routing decisions, they specify both the state updates and the next destination.\n\n## Errors are part of the flow\n\nTransient failures get retries, LLM-recoverable errors loop back with context, user-fixable problems pause for input, and unexpected errors bubble up for debugging.\n\n## Human input is first-class\n\nThe `interrupt()` function pauses execution indefinitely, saves all state, and resumes exactly where it left off when you provide input. When combined with other operations in a node, it must come first.\n\n## Graph structure emerges naturally [...] To implement an agent in LangGraph, you will usually follow the same five steps.\n\n## \u200b Step 1: Map out your workflow as discrete steps\n\nStart by identifying the distinct steps in your process. Each step will become a node (a function that does one specific thing). Then, sketch how these steps connect to each other. The arrows in this diagram show possible paths, but the actual decision of which path to take happens inside each node. Now that we’ve identified the components in our workflow, let’s understand what each node needs to do:',
#   'score': 0.8684817}]
